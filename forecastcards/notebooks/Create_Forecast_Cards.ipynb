# %%
import os
import csv
import pandas as pd

# !pip install -e ../../../forecastcards
import forecastcards

try:
    from google.colab import files   # Works when running in Google Colab
except ImportError:
    # Falls back to this when running locally
    import shutil
    class files:
        @staticmethod
        def download(path):
            dest = os.path.join(os.path.expanduser("~"), "Downloads", os.path.basename(path))
            shutil.copy(path, dest)
            print(f"Saved to {dest}")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Obtaining file:///C:/Users/hmod225/Documents/Code/forecastcards
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Checking if build backend supports build_editable: started
#   Checking if build backend supports build_editable: finished with status 'done'
#   Getting requirements to build editable: started
#   Getting requirements to build editable: finished with status 'done'
#   Preparing editable metadata (pyproject.toml): started
#   Preparing editable metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: pandas in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from forecastcards==0.1.0.dev0) (3.0.3)
# Requirement already satisfied: requests in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from forecastcards==0.1.0.dev0) (2.34.2)
# Requirement already satisfied: goodtables in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from forecastcards==0.1.0.dev0) (2.5.4)
# Requirement already satisfied: tableschema in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from forecastcards==0.1.0.dev0) (1.21.0)
# Requirement already satisfied: graphviz in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from forecastcards==0.1.0.dev0) (0.21)
# Requirement already satisfied: statsmodels in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from forecastcards==0.1.0.dev0) (0.14.6)
# Requirement already satisfied: jupyter in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from forecastcards==0.1.0.dev0) (1.1.1)
# Requirement already satisfied: six>=1.9 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from goodtables->forecastcards==0.1.0.dev0) (1.17.0)
# Requirement already satisfied: click>=6.6 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from goodtables->forecastcards==0.1.0.dev0) (8.4.1)
# Requirement already satisfied: click-default-group in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from goodtables->forecastcards==0.1.0.dev0) (1.2.4)
# Requirement already satisfied: simpleeval>=0.9 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from goodtables->forecastcards==0.1.0.dev0) (1.0.7)
# Requirement already satisfied: statistics>=1.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from goodtables->forecastcards==0.1.0.dev0) (1.0.3.5)
# Requirement already satisfied: tabulator>=1.40 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from goodtables->forecastcards==0.1.0.dev0) (1.53.5)
# Requirement already satisfied: datapackage>=1.10 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from goodtables->forecastcards==0.1.0.dev0) (1.15.4)
# Requirement already satisfied: colorama in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from click>=6.6->goodtables->forecastcards==0.1.0.dev0) (0.4.6)
# Requirement already satisfied: chardet>=3.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from datapackage>=1.10->goodtables->forecastcards==0.1.0.dev0) (7.4.3)
# Requirement already satisfied: jsonschema>=2.5 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from datapackage>=1.10->goodtables->forecastcards==0.1.0.dev0) (4.26.0)
# Requirement already satisfied: unicodecsv>=0.14 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from datapackage>=1.10->goodtables->forecastcards==0.1.0.dev0) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.10 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from datapackage>=1.10->goodtables->forecastcards==0.1.0.dev0) (3.1.1)
# Requirement already satisfied: dataflows-tabulator>=1.29 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from datapackage>=1.10->goodtables->forecastcards==0.1.0.dev0) (1.54.3)
# Requirement already satisfied: boto3>=1.9 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from dataflows-tabulator>=1.29->datapackage>=1.10->goodtables->forecastcards==0.1.0.dev0) (1.43.19)
# Requirement already satisfied: ijson>=3.0.3 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from dataflows-tabulator>=1.29->datapackage>=1.10->goodtables->forecastcards==0.1.0.dev0) (3.5.0)
# Requirement already satisfied: jsonlines>=1.1 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from dataflows-tabulator>=1.29->datapackage>=1.10->goodtables->forecastcards==0.1.0.dev0) (4.0.0)
# Requirement already satisfied: sqlalchemy>=0.9.6 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from dataflows-tabulator>=1.29->datapackage>=1.10->goodtables->forecastcards==0.1.0.dev0) (2.0.50)
# Requirement already satisfied: linear-tsv>=1.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from dataflows-tabulator>=1.29->datapackage>=1.10->goodtables->forecastcards==0.1.0.dev0) (1.1.0)
# Requirement already satisfied: xlrd>=1.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from dataflows-tabulator>=1.29->datapackage>=1.10->goodtables->forecastcards==0.1.0.dev0) (2.0.2)
# Requirement already satisfied: openpyxl>=2.6 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from dataflows-tabulator>=1.29->datapackage>=1.10->goodtables->forecastcards==0.1.0.dev0) (3.1.5)
# Requirement already satisfied: botocore<1.44.0,>=1.43.19 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from boto3>=1.9->dataflows-tabulator>=1.29->datapackage>=1.10->goodtables->forecastcards==0.1.0.dev0) (1.43.19)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from boto3>=1.9->dataflows-tabulator>=1.29->datapackage>=1.10->goodtables->forecastcards==0.1.0.dev0) (1.1.0)
# Requirement already satisfied: s3transfer<0.19.0,>=0.18.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from boto3>=1.9->dataflows-tabulator>=1.29->datapackage>=1.10->goodtables->forecastcards==0.1.0.dev0) (0.18.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from botocore<1.44.0,>=1.43.19->boto3>=1.9->dataflows-tabulator>=1.29->datapackage>=1.10->goodtables->forecastcards==0.1.0.dev0) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from botocore<1.44.0,>=1.43.19->boto3>=1.9->dataflows-tabulator>=1.29->datapackage>=1.10->goodtables->forecastcards==0.1.0.dev0) (2.7.0)
# Requirement already satisfied: attrs>=19.2.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jsonlines>=1.1->dataflows-tabulator>=1.29->datapackage>=1.10->goodtables->forecastcards==0.1.0.dev0) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jsonschema>=2.5->datapackage>=1.10->goodtables->forecastcards==0.1.0.dev0) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jsonschema>=2.5->datapackage>=1.10->goodtables->forecastcards==0.1.0.dev0) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jsonschema>=2.5->datapackage>=1.10->goodtables->forecastcards==0.1.0.dev0) (2026.5.1)
# Requirement already satisfied: et-xmlfile in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from openpyxl>=2.6->dataflows-tabulator>=1.29->datapackage>=1.10->goodtables->forecastcards==0.1.0.dev0) (2.0.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from referencing>=0.28.4->jsonschema>=2.5->datapackage>=1.10->goodtables->forecastcards==0.1.0.dev0) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from requests->forecastcards==0.1.0.dev0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from requests->forecastcards==0.1.0.dev0) (3.17)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from requests->forecastcards==0.1.0.dev0) (2026.5.20)
# Requirement already satisfied: greenlet>=1 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from sqlalchemy>=0.9.6->dataflows-tabulator>=1.29->datapackage>=1.10->goodtables->forecastcards==0.1.0.dev0) (3.5.1)
# Requirement already satisfied: docutils>=0.3 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from statistics>=1.0->goodtables->forecastcards==0.1.0.dev0) (0.23)
# Requirement already satisfied: cached-property>=1.5 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from tableschema->forecastcards==0.1.0.dev0) (2.0.1)
# Requirement already satisfied: isodate>=0.5.4 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from tableschema->forecastcards==0.1.0.dev0) (0.7.2)
# Requirement already satisfied: rfc3986>=1.1.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from tableschema->forecastcards==0.1.0.dev0) (2.0.0)
# Requirement already satisfied: notebook in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jupyter->forecastcards==0.1.0.dev0) (7.5.6)
# Requirement already satisfied: jupyter-console in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jupyter->forecastcards==0.1.0.dev0) (6.6.3)
# Requirement already satisfied: nbconvert in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jupyter->forecastcards==0.1.0.dev0) (7.17.1)
# Requirement already satisfied: ipykernel in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jupyter->forecastcards==0.1.0.dev0) (7.2.0)
# Requirement already satisfied: ipywidgets in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jupyter->forecastcards==0.1.0.dev0) (8.1.8)
# Requirement already satisfied: jupyterlab in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jupyter->forecastcards==0.1.0.dev0) (4.5.7)
# Requirement already satisfied: comm>=0.1.1 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from ipykernel->jupyter->forecastcards==0.1.0.dev0) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from ipykernel->jupyter->forecastcards==0.1.0.dev0) (1.8.21)
# Requirement already satisfied: ipython>=7.23.1 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from ipykernel->jupyter->forecastcards==0.1.0.dev0) (9.14.0)
# Requirement already satisfied: jupyter-client>=8.8.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from ipykernel->jupyter->forecastcards==0.1.0.dev0) (8.8.0)
# Requirement already satisfied: jupyter-core!=6.0.*,>=5.1 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from ipykernel->jupyter->forecastcards==0.1.0.dev0) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from ipykernel->jupyter->forecastcards==0.1.0.dev0) (0.2.2)
# Requirement already satisfied: nest-asyncio>=1.4 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from ipykernel->jupyter->forecastcards==0.1.0.dev0) (1.6.0)
# Requirement already satisfied: packaging>=22 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from ipykernel->jupyter->forecastcards==0.1.0.dev0) (26.2)
# Requirement already satisfied: psutil>=5.7 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from ipykernel->jupyter->forecastcards==0.1.0.dev0) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from ipykernel->jupyter->forecastcards==0.1.0.dev0) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from ipykernel->jupyter->forecastcards==0.1.0.dev0) (6.5.6)
# Requirement already satisfied: traitlets>=5.4.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from ipykernel->jupyter->forecastcards==0.1.0.dev0) (5.15.0)
# Requirement already satisfied: decorator>=5.1.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter->forecastcards==0.1.0.dev0) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter->forecastcards==0.1.0.dev0) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter->forecastcards==0.1.0.dev0) (0.20.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter->forecastcards==0.1.0.dev0) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter->forecastcards==0.1.0.dev0) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from ipython>=7.23.1->ipykernel->jupyter->forecastcards==0.1.0.dev0) (0.6.3)
# Requirement already satisfied: wcwidth in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter->forecastcards==0.1.0.dev0) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel->jupyter->forecastcards==0.1.0.dev0) (0.8.7)
# Requirement already satisfied: platformdirs>=2.5 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jupyter-core!=6.0.*,>=5.1->ipykernel->jupyter->forecastcards==0.1.0.dev0) (4.10.0)
# Requirement already satisfied: executing>=1.2.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter->forecastcards==0.1.0.dev0) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter->forecastcards==0.1.0.dev0) (3.0.1)
# Requirement already satisfied: pure-eval in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel->jupyter->forecastcards==0.1.0.dev0) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from ipywidgets->jupyter->forecastcards==0.1.0.dev0) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from ipywidgets->jupyter->forecastcards==0.1.0.dev0) (3.0.16)
# Requirement already satisfied: async-lru>=1.0.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jupyterlab->jupyter->forecastcards==0.1.0.dev0) (2.3.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jupyterlab->jupyter->forecastcards==0.1.0.dev0) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jupyterlab->jupyter->forecastcards==0.1.0.dev0) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jupyterlab->jupyter->forecastcards==0.1.0.dev0) (2.3.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jupyterlab->jupyter->forecastcards==0.1.0.dev0) (2.19.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jupyterlab->jupyter->forecastcards==0.1.0.dev0) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jupyterlab->jupyter->forecastcards==0.1.0.dev0) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in C:\Program Files\Python311\Lib\site-packages (from jupyterlab->jupyter->forecastcards==0.1.0.dev0) (65.5.0)
# Requirement already satisfied: anyio in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (4.13.0)
# Requirement already satisfied: httpcore==1.* in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (0.5.4)
# Requirement already satisfied: nbformat>=5.3.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (0.25.0)
# Requirement already satisfied: pywinpty>=2.0.1 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (3.0.3)
# Requirement already satisfied: send2trash>=1.8.2 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (1.9.0)
# Requirement already satisfied: babel>=2.10 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (0.14.0)
# Requirement already satisfied: argon2-cffi-bindings in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jinja2>=3.0.3->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (3.0.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (4.1.0)
# Requirement already satisfied: pyyaml>=5.3 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (6.0.3)
# Requirement already satisfied: rfc3339-validator in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (0.1.1)
# Requirement already satisfied: fqdn in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (1.5.1)
# Requirement already satisfied: isoduration in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (20.11.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (1.1.0)
# Requirement already satisfied: uri-template in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from nbconvert->jupyter->forecastcards==0.1.0.dev0) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->forecastcards==0.1.0.dev0) (6.3.0)
# Requirement already satisfied: defusedxml in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from nbconvert->jupyter->forecastcards==0.1.0.dev0) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from nbconvert->jupyter->forecastcards==0.1.0.dev0) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from nbconvert->jupyter->forecastcards==0.1.0.dev0) (3.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from nbconvert->jupyter->forecastcards==0.1.0.dev0) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from nbconvert->jupyter->forecastcards==0.1.0.dev0) (1.5.1)
# Requirement already satisfied: webencodings in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->forecastcards==0.1.0.dev0) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->forecastcards==0.1.0.dev0) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (2.21.2)
# Requirement already satisfied: lark>=1.2.2 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (1.3.1)
# Requirement already satisfied: cffi>=1.0.1 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (2.0.0)
# Requirement already satisfied: pycparser in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from beautifulsoup4->nbconvert->jupyter->forecastcards==0.1.0.dev0) (2.8.4)
# Requirement already satisfied: arrow>=0.15.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (1.4.0)
# Requirement already satisfied: tzdata in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter->forecastcards==0.1.0.dev0) (2026.2)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from pandas->forecastcards==0.1.0.dev0) (2.4.6)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from statsmodels->forecastcards==0.1.0.dev0) (1.17.1)
# Requirement already satisfied: patsy>=0.5.6 in C:\Users\hmod225\AppData\Roaming\Python\Python311\site-packages (from statsmodels->forecastcards==0.1.0.dev0) (1.0.2)
# Building wheels for collected packages: forecastcards
#   Building editable for forecastcards (pyproject.toml): started
#   Building editable for forecastcards (pyproject.toml): finished with status 'done'
#   Created wheel for forecastcards: filename=forecastcards-0.1.0.dev0-0.editable-py3-none-any.whl size=7572 sha256=f3a5bafed82a735585071161b6b07b106127277a8f0ed1dd3e4b6f3c46ee3515
#   Stored in directory: C:\Users\hmod225\AppData\Local\Temp\pip-ephem-wheel-cache-g36sv2pe\wheels\95\a5\c1\1583449b269f1915f83aab5c882ffbe89776032b5036fbd04e
# Successfully built forecastcards
# Installing collected packages: forecastcards
#   Attempting uninstall: forecastcards
#     Found existing installation: forecastcards 0.1.0.dev0
#     Uninstalling forecastcards-0.1.0.dev0:
#       Successfully uninstalled forecastcards-0.1.0.dev0
# Successfully installed forecastcards-0.1.0.dev0
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 6
#       2 import csv
#       3 import pandas as pd
#       4
#       5 get_ipython().system('pip install -e ../../../forecastcards')
# ----> 6 import forecastcards
#       7
#       8 try:
#       9     from google.colab import files   # Works when running in Google Colab
#
# ModuleNotFoundError: No module named 'forecastcards'

# %% [markdown]
# # Create a Project

# %% [markdown]
# ## Create a project file

# %%
#@markdown ### Specify a filename for a new Project file, starting with `project`
project_filename = "project.csv" #@param {type:"string"}

s = forecastcards.Card_schema()
project_card_fields = s.schema_fields['project']

with open(project_filename, 'w') as myfile:
    wr = csv.writer(myfile)
    wr.writerow(project_card_fields)
    
#for f in project_card_fields: print(f)

# %% [markdown]
# ## Create a project ID
#
# Project ID should be a unique value from any other cardsets that you might want to combine it with.  This checks to see if your proposed project id conflicts with a standard set of repositories, but feel free to add your own checks as well.

# %%
project_id   = "abc123" #@param {type:"string"}

check_cardset_1 = "../examples" #@param {type:"string"}
check_cardset_2 = "" #@param {type:"string"}
check_cardset_3 = "" #@param {type:"string"}
check_cardset_4  = "" #@param {type:"string"}


cardsets_to_check = [check_cardset_1,
                     check_cardset_2,
                     check_cardset_3,
                     check_cardset_4]


cs_with_project_id = []
for cs_loc in cardsets_to_check:
  if cs_loc: 
    
    cs_loc_orig = cs_loc
    
    if cs_loc.find('github')>=0: 
      cs_loc = forecastcards.github_url_to_dict(cs_loc)
    
    cs = forecastcards.Cardset(data_loc=cs_loc,validate=False)
    
    if project_id in cs.projects: 
      cs_with_project_id.append(cs_loc_orig)

if cs_with_project_id:
  print("!!! Select a different project ID. Duplicate Project ID found in following cardsets:","\n".join(cs_with_project_id))
else:
  print("Project ID good to go – not used in specified cardsets")

# %% [markdown]
# ## Add Project variables

# %%
agency      = "None" #@param {type:"string"}
description = "None" #@param {type:"string"}
project_type      = 'hov' #@param ["hov", "road-capacity-expansion", "transit-priority", "road-diet", "bike-facility", "new-roadway", "land-use", "other"]{allow-input: true}
year_open_planned =  1900 #@param {type:"slider", min:1900, max:2100, step:1}
year_horizon = 1920 
date_open_actual  =  '1901-01-01' #@param {type:"date"}

if year_open_planned == '1900':
  year_open_planned = None
if date_open_actual == '1901-01-01':
  date_open_actual = None

project_var_row = [project_id, agency, description, project_type, year_open_planned, year_horizon, date_open_actual]


for var_name,var_value in zip(project_card_fields,project_var_row):
  print(var_name,": ",var_value)

# %% [markdown]
# ## Review Project values before writing to CSV

# %%
pd.read_csv(project_filename)

# %% [markdown]
# ## Write Project CSV

# %%
with open(project_filename, 'a') as myfile:
    wr = csv.writer(myfile)
    wr.writerow(project_var_row)

# %% [markdown]
# ## Download Project CSV

# %%
files.download(project_filename)

# %% [markdown]
# # Points of Interest

# %% [markdown]
# ## Create a Points of Interest File

# %%
#@markdown ### Specify a filename for a new Points of Interest File, starting with `poi`
poi_filename = "poi-101.csv" #@param {type:"string"}

s = forecastcards.Card_schema()
poi_card_fields = s.schema_fields['poi']

with open(poi_filename, 'w') as myfile:
    wr = csv.writer(myfile)
    wr.writerow(poi_card_fields)

# %% [markdown]
# ## Add Point of Interests to File
#
# Append a point of interest to an existing file.

# %% [markdown]
# ### Create a point of interest record

# %%
poi_filename = "poi-101.csv" #@param {type:"string"}
poi_id = "p126" #@param {type:"string"}
poi_short_name = "45th St I-5 NB On Ramp" #@param {type:"string"}
facility_name = "on ramp" #@param {type:"string"}
start = "45th Street" #@param {type:"string"}
end = "NB I-5" #@param {type:"string"}
area_type = 'urban' #@param ["urban","suburban","exurban","rural","other","unkown"]
facility_type  = 'highway' #@param ["highway","transit"] {allow-input: true}
functional_class = 'Ramp' #@param ["Freeway","Principal Arterial","Minor Arterial","Major Collector","Minor Collector","Local","Ramp"]
features = []
state = "WA" #@param {type:"string"}
jurisdiction = "WA DOT" #@param {type:"string"}
poi_description = "on ramp from 45th St to NB I-5" #@param {type:"string"}

poi_var_row = [poi_id,poi_short_name,facility_name,start,end,area_type,facility_type,functional_class,features,state,jurisdiction,poi_description]

for var_name,var_value in zip(poi_card_fields,poi_var_row):
  print(var_name,": ",var_value)

# %% [markdown]
# ### Write values to POI CSV
#
# - If these values look good, write them to the CSV
# - If not, you can go back and change them before writing.

# %%
with open(poi_filename, 'a') as myfile:
    wr = csv.writer(myfile)
    wr.writerow(poi_var_row)

# %% [markdown]
# ### Add more POIs to POI CSV
#
#  - Go back to "Add a Point of Interest to File" to add more POIs
#  - Write the values and then review the whole CSV before downloading

# %%
pd.read_csv(poi_filename)

# %% [markdown]
# ## Download POI CSV
#
# If the complete CSV looks good, download it

# %%
pd.read_csv(poi_filename)

# %%
files.download(poi_filename)

# %% [markdown]
# # Observations

# %% [markdown]
# ## Create an observations file

# %%
#@markdown ### Specify a filename for a new Observations File
observations_filename = "observations-101.csv" #@param {type:"string"}

s = forecastcards.Card_schema()
observations_card_fields = s.schema_fields['observations']

with open(observations_filename, 'w') as myfile:
    wr = csv.writer(myfile)
    wr.writerow(observations_card_fields)

# %% [markdown]
# ## Add observations to file

# %% [markdown]
# ### Reference POI file
#
# Identify the forecast cardset or POI file in this space to be used to find POI IDs in case you need them for reference

# %%
poi_filename = "poi101.csv" #@param {type:"string"}
avail_obs_ids = pd.read_csv(poi_filename)['poi_id'].tolist()
for p in avail_obs_ids:
  print (p)

# %% [markdown]
# ### Create an observation

# %%
observations_filename = "observations-101.csv" #@param {type:"string"}

obs_id = 'None' #@param {type:"string"}
poi_id = "None" #@param {type:"string"}
forecast_match_id = 'None' #@param {type:"string"}
equip_id = 'None'  #@param {type:"string"}
equip_type =  'video detection' #@param["hand", "tube", "loop-detector", "radar", "video detection", "video replay", "other", "unknown"]
obs_date = '2001-01-01' #@param {type:"date"}

#@markdown **Times should be in HH:MM:SS format**
#@markdown **Daily values should be left as None or set to: <br> -  `start`: 00:00:00 <br> - `end`: 24:00:00**
time_start = None #@param {type:"string"}
time_end = None #@param {type:"string"}

obs_variable = "volume" #@param ["volume", "ridership", "boardings", "alightings", "speed", "travel-time", "hov2-volume", "hov3-volume"]
obs_value= -1 #@param {type:"number"}

if obs_date == '1901-01-01':
  print("!!! NEED TO FILL IN OBSERVATION DATE")
if obs_id == 'None':
  print("!!! NEED TO FILL IN OBSERVATION ID")
if poi_id == 'None':
  print("!!! NEED TO FILL IN POI ID")
if obs_value == -1:
  print("!!! NEED TO FILL IN OBSERVED VALUE")

observations_var_row = [obs_id,poi_id,forecast_match_id,equip_id,equip_type,obs_date,time_start,time_end,obs_variable,obs_value]

for var_name,var_value in zip(observations_card_fields,observations_var_row):
  print(var_name,": ",var_value)

# %% [markdown]
# ### Write observation values to CSV
#
# - If these values look good, write them to the CSV
# - If not, you can go back and change them before writing.

# %%
with open(observations_filename, 'a') as myfile:
    wr = csv.writer(myfile)
    wr.writerow(observations_var_row)

# %% [markdown]
# ### Add more Observations to Observation CSV
#
#  - Go back to "Add an observation to file" to add more POIs
#  - Write the values and then review the whole CSV before downloading

# %%
pd.read_csv(observations_filename)

# %% [markdown]
# ## Download Observations CSV
#
# If the complete CSV looks good, download it

# %%
pd.read_csv(observations_filename)

# %%
files.download(observations_filename)

# %% [markdown]
# #  Add a Scenario

# %% [markdown]
# ## Create a scenario file

# %%
#@markdown ### Specify a filename for a new Scenario File
scenario_filename = "scenario.csv" #@param {type:"string"}

s = forecastcards.Card_schema()
scenario_card_fields = s.schema_fields['scenario']

with open(scenario_filename, 'w') as myfile:
    wr = csv.writer(myfile)
    wr.writerow(scenario_card_fields)
    
#for f in scenario_card_fields: print(f)

# %% [markdown]
# ## Add scenario to file

# %% [markdown]
# ### Create a scenario record

# %%
scenario_filename = "scenarios.csv" #@param {type:"string"}

run_id = 'None' #@param {type:"string"}
project_id = 'None' #@param {type:"string"}
scenario_id = 'None' #@param {type:"string"}
scenario_date = '1901-01-01' #@param {type:"date"}
scenario_name = 'None' #@param {type:"string"}
forecast_system = 'None' #@param {type:"string"}
forecast_system_type = 'trendline' #@param ["trendline", "pop-growth-rates", "travel-model", "professional-judgement", "unknown", "other"]
forecast_creation_date ='1901-01-01' #@param {type:"date"}
forecaster_type = 'unknown' #@param ["consultant", "state DOT", "MPO", "local", "other", "unknown"]

if scenario_date == '1901-01-01':
  print("!!! NEED TO FILL IN SCENARIO DATE")
if forecast_creation_date == '1901-01-01':
  print("!!! NEED TO FILL IN FORECAST CREATION DATE")
  
scenario_var_row = [run_id,project_id,scenario_id,scenario_date,scenario_name,forecast_system,forecast_system_type,forecast_creation_date,forecaster_type]
for var_name,var_value in zip(scenario_card_fields,scenario_var_row):
  print(var_name,": ",var_value)

# %% [markdown]
# ### Write scenario values to CSV
#
# - If these values look good, write them to the CSV
# - If not, you can go back and change them before writing.

# %%
with open(scenario_filename, 'a') as myfile:
    wr = csv.writer(myfile)
    wr.writerow(scenario_var_row)

# %% [markdown]
# ### Add more Scenarios to Scenario CSV
#
#  - Go back to "Add a scenario to file" to add more scenarios
#  - Write the values and then review the whole CSV before downloading

# %%
pd.read_csv(scenario_filename)

# %% [markdown]
# ## Download Scenario CSV
#
# If the complete CSV looks good, download it

# %%
pd.read_csv(scenario_filename)

# %%
files.download(observations_filename)

# %% [markdown]
# # Add a Forecast

# %% [markdown]
# ## Create a forecast

# %%
#@markdown ### Specify a filename for a new Forecast File
forecast_filename = "forecast-.csv" #@param {type:"string"}

s = forecastcards.Card_schema()
forecast_card_fields = s.schema_fields['forecast']

with open(forecast_filename, 'w') as myfile:
    wr = csv.writer(myfile)
    wr.writerow(forecast_card_fields)
    
for f in forecast_card_fields: print(f)

# %% [markdown]
# ## Add forecast to file

# %% [markdown]
# ### Create a forecast record

# %%
forecast_filename = "forecast-.csv" #@param {type:"string"}

forecast_id = 'None' #@param {type:"string"}
run_id = 'None' #@param {type:"string"}
poi_id = 'None' #@param {type:"string"}
forecast_match_id = 'None' #@param {type:"string"}

#@markdown **Times should be in HH:MM:SS format**
#@markdown **Daily values should be left as None or set to: <br> -  `start`: 00:00:00 <br> - `end`: 24:00:00**
start_time = 'None' #@param {type:"string"}
end_time   = 'None' #@param {type:"string"}

forecast_variable = "volume" #@param ["volume", "ridership", "boardings", "alightings", "speed", "travel-time", "hov2-volume", "hov3-volume"]
forecast_value = -1 #@param {type:"number"}


if forecast_id == 'None':
  print("!!! NEED TO FILL IN Forecast ID")
if run_id == 'None':
  print("!!! NEED TO FILL IN Run ID")
if poi_id == 'None':
  print("!!! NEED TO FILL IN POI ID")
if forecast_match_id == 'None':
  print("!!! NEED TO FILL IN Forecast Match ID")
if forecast_value == -1:
  print("!!! NEED TO FILL IN FORECAST VALUE")  

forecast_var_row = [forecast_id,run_id,poi_id,forecast_match_id,start_time,end_time,forecast_variable,forecast_value]
for var_name,var_value in zip(forecast_card_fields,forecast_var_row):
  print(var_name,": ",var_value)

# %% [markdown]
# ### Write forecast values to CSV
#
# - If these values look good, write them to the CSV
# - If not, you can go back and change them before writing.

# %%
with open(forecast_filename, 'a') as myfile:
    wr = csv.writer(myfile)
    wr.writerow(forecast_var_row)

# %% [markdown]
# ### Add more forecast to forecast CSV
#
#  - Go back to "Add a forecast to file" to add more forecasts
#  - Write the values and then review the whole CSV before downloading

# %%
pd.read_csv(forecast_filename)

# %% [markdown]
# ## Download forecast CSV
#
# If the complete CSV looks good, download it

# %%
pd.read_csv(forecast_filename)

# %%
files.download(forecast_filename)
